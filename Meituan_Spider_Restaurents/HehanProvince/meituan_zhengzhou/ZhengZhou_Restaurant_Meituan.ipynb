# %% [markdown]
# # Collect restaurant information of Zhengzhou
# - Author: Yiran Jing
#
# Build Meituan AppSpider to Collect 1000 restaurant information of Zhengzhou from Meituan app.
#
# Scraping content:
# 店铺名称','页面id','类别','品牌名称','品牌id','品牌logo','评分',
# '平均价格','最低价格','所属地区','地区Id','纬度','经度','详细地址',
# '楼层','地铁站id','停车信息','优惠套餐情况','营业时间','联系电话',
# '累计售出份数','餐厅简介','特色菜','是否小吃','有无外卖','上周订单数',
# '历史订单数','wifi','支持预定
#
# Reference:
#
# 1. https://github.com/hahaha108/meituanAppSpider
# 2. https://blog.csdn.net/slphahaha/article/details/81145404
#
# Details in **spider_develop.py**

# %%
import requests
import json
from lxml import etree
import pandas as pd
import re
import math
import urllib
import urllib.request as urllib2
import xlsxwriter
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings

# set headers
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'}

# %%
from spider_develop import MeituanSpider

# save_mode ：txt存储为txt文件，csv存储为csv文件，db存储在mysql数据库中，无输入默认为txt
# spider = MeituanSpider(save_mode='txt')
# spider = MeituanSpider(save_mode='csv')
spider = MeituanSpider()

spider.run()
# Out:
# >>>> we are in files.
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=0&limit=25
# 已成功请求25个商家信息
# 已成功获取25个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=25&limit=25
# 已成功请求50个商家信息
# 已成功获取50个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=50&limit=25
# 已成功请求75个商家信息
# 已成功获取75个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=75&limit=25
# 已成功请求100个商家信息
# 已成功获取100个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=100&limit=25
# 已成功请求125个商家信息
# 已成功获取125个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=125&limit=25
# 已成功请求150个商家信息
# 已成功获取150个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=150&limit=25
# 已成功请求175个商家信息
# 已成功获取175个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=175&limit=25
# 已成功请求200个商家信息
# 已成功获取200个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=200&limit=25
# 已成功请求225个商家信息
# 已成功获取225个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=225&limit=25
# 已成功请求250个商家信息
# 已成功获取250个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=250&limit=25
# 已成功请求275个商家信息
# 已成功获取275个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=275&limit=25
# 已成功请求300个商家信息
# 已成功获取300个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=300&limit=25
# 已成功请求325个商家信息
# 已成功获取325个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=325&limit=25
# 已成功请求350个商家信息
# 已成功获取350个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=350&limit=25
# 已成功请求375个商家信息
# 已成功获取375个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=375&limit=25
# 已成功请求400个商家信息
# 已成功获取400个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=400&limit=25
# 已成功请求425个商家信息
# 已成功获取425个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=425&limit=25
# 已成功请求450个商家信息
# 已成功获取450个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=450&limit=25
# 已成功请求475个商家信息
# 已成功获取475个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=475&limit=25
# 已成功请求500个商家信息
# 已成功获取500个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=500&limit=25
# 已成功请求525个商家信息
# 已成功获取525个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=525&limit=25
# 已成功请求550个商家信息
# 已成功获取550个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=550&limit=25
# 已成功请求575个商家信息
# 已成功获取575个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=575&limit=25
# 已成功请求600个商家信息
# 已成功获取600个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=600&limit=25
# 已成功请求625个商家信息
# 已成功获取625个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=625&limit=25
# 已成功请求650个商家信息
# 已成功获取650个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=650&limit=25
# 已成功请求675个商家信息
# 已成功获取675个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=675&limit=25
# 已成功请求700个商家信息
# 已成功获取700个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=700&limit=25
# 已成功请求725个商家信息
# 已成功获取725个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=725&limit=25
# 已成功请求750个商家信息
# 已成功获取750个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=750&limit=25
# 已成功请求775个商家信息
# 已成功获取775个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=775&limit=25
# 已成功请求800个商家信息
# 已成功获取800个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=800&limit=25
# 已成功请求825个商家信息
# 已成功获取825个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=825&limit=25
# 已成功请求850个商家信息
# 已成功获取850个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=850&limit=25
# 已成功请求875个商家信息
# 已成功获取875个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=875&limit=25
# 已成功请求900个商家信息
# 已成功获取900个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=900&limit=25
# 已成功请求925个商家信息
# 已成功获取925个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=925&limit=25
# 已成功请求950个商家信息
# 已成功获取950个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=950&limit=25
# 已成功请求975个商家信息
# 已成功获取975个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=975&limit=25
# 已成功请求1000个商家信息
# 已成功获取1000个商家信息
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
# http://api.meituan.com/group/v4/deal/select/city/73/cate/1?sort=solds&hasGroup=true&mpt_cate1=1&offset=1000&limit=25
